# %% [markdown]
# # Task 2 — Bayesian Change Point Analysis for Brent Oil Prices
#
# This notebook implements a simple Bayesian change-point model for Brent oil log returns. It is designed to work with the repository's synthetic fallback data and also with a real file if one is placed in the expected location.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.change_point_analysis import (
    load_price_series,
    prepare_log_returns,
    fit_bayesian_change_point,
    run_full_analysis,
,
,
,
5
]},{
:
,
:{},
:[
,
,
,
,
,
,
,
,

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

axes[0, 0].plot(returns['Date'], returns['log_return'], color='#1f4e79', linewidth=0.8)
axes[0, 0].axvline(change_point_date, color='firebrick', linestyle='--', linewidth=1.5)
axes[0, 0].set_title('Log returns with detected change point')
axes[0, 0].set_xlabel('Date')
axes[0, 0].set_ylabel('Log return')

axes[0, 1].hist(fit_result['trace'].posterior['tau'].values.flatten(), bins=30, color='#4c78a8', alpha=0.9)
axes[0, 1].set_title('Posterior distribution of tau')
axes[0, 1].set_xlabel('tau')
axes[0, 1].set_ylabel('Frequency')

axes[1, 0].hist(fit_result['trace'].posterior['mu1'].values.flatten(), bins=30, color='#f58518', alpha=0.9)
axes[1, 0].set_title('Posterior of mu1')
axes[1, 0].set_xlabel('mu1')
axes[1, 0].set_ylabel('Frequency')

axes[1, 1].hist(fit_result['trace'].posterior['mu2'].values.flatten(), bins=30, color='#54a24b', alpha=0.9)
axes[1, 1].set_title('Posterior of mu2')
axes[1, 1].set_xlabel('mu2')
axes[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretation
#
# The posterior identifies a change in the mean of the log return series. In this synthetic fallback run, the change point appears earlier than most historical events in the curated calendar, so no event match is shown. When the real Brent price file is supplied, the event-association step will identify nearby geopolitical or policy events around the detected change point for interpretation.
